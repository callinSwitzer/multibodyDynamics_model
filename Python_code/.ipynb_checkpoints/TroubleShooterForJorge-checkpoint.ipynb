# %%
# coding: utf-8

#     4/4/17- Setting up my model (Model 1) in MATLAB using ode45
#     Models 2-7 since then (and even more errors/fixes)
#     Model 8 was essentially refined on 6/29/17
#     7/6/17- Model 9 development will incorporate our cost function and 
#         multiple wing strokes.
#     8/7/17- Model 10(a?) will do all of the above for SEVERAL full run 
#         throughs. Model 10(b?) will have a Gaussian cost function. 
#             a.k.a. no more window!
#     9/4/17- FIXED K and c
#     9/6/17- Fixed tau to have a maximum value of 10000 g*(cm^2)/(s^2)
#     2/8/18- Eliminated the need for global variables and implemented 
#         %structs that are passed into the ODE.
#     3/6/18- Model 11 is born.
#         Restructured the ENTIRE layout of the variables to have nested
#         structs which contain what we want.
#         hws contains a 2500x1 struct of: 
#             ICs, F, alpha, tau, Q, cost, NewICs
#         Each hws is nested in a 100x1 large struct for Qstore and Winstore
#     7/3/18- Fixed a MAJOR error in the resting angle of the torsional spring.
#         Now there is the appropriate restorative force.
#     7/18/18- Model 12 was born.
#         Fixed another MAJOR error. tau_abdo is now a fixed force (as
#         originally intended), needed to fix myODE and remove the
#         sinusoidal component of the applied torque.
#     ~8/17/18- Incorporated LengthScaleFactor to change the size of the model.
#     10/16/18- Incorporated Size
#     1/7/19- Finally attempting a formal Model Predictive Control (MPC)
#     1/31/19- Corrected issues pertaining to the Moment of Inertia.
#         myODE5 was born.
#         1) incorrect multiplication in myODE4,
#         2) accounting for parallel axis theorem (due to petiole length
#         extension) in myODE4.
#     2/14/19- For the sake of efficiency, lines 184, and 314 were muted
#         to no longer create the Qstore struct. 
# ** Conversion to Python **
#     2/25/19- Code being migrated to Python. This transition will switch to 
#         fixed time steps. This transition will likely lead to the use of a 
#         GPU or Amazon Web Services. 
#     4/8/19- Added wing torque term as a fourth control parameter (tau_w) to 
#         add the option of making the model fully actuated. I have also saved
#         the output of this file to be pre_Winstore. A MATLAB script will 
#         convert this file into the structure I desire in MATLAB. 
#         Single core processing.
#     4/11/19- Created multi-core verson of the code. This uses the @jit
#         decorator in the numba package to use multi-processing.
#     5/1/19- Went back to global variables (I know, it's not the best 
#         practice, but I have no patience at this time).
#     5/17/19- Got the sucker to run with huge help from Callin Switzer. Woo!
# 
#     12b is for horizontal aggressive maneuver
#     12c is for vertical aggressive maneuver
#     12h is for sum of prime number sines


#____________________________________________________

# The python preamble
## We the People, in Order to form a perfect Union,...
#import matplotlib.pyplot as plt
import numpy as np
#import os
#import pandas as pd
#import seaborn as sns
#from scipy.integrate import odeint
from scipy.io import savemat #This is imported to save .mat files
#import random
import time
from datetime import datetime
import sys
import multiprocessing 
#from multiprocessing import Pool, cpu_count
import importlib
import functools
import multibodyDynamics_12h #Note: that this is a custom-written file which
               #contains the ODEs to run the code.
from collections import OrderedDict

sys_version = sys.version; #The system version for troubleshooting
print(sys_version)

tstamp_start = datetime.now()
print(tstamp_start)

#Packages originally included here which I have muted out.
#matplotlib inline
# from matplotlib import cm
from matplotlib import pyplot as plt #UNMUTE THIS WHEN TROUBLESHOOTING
# from pylab import plot,xlabel,ylabel,title,legend,figure,subplots
# import seaborn as sb
# import matplotlib.pylab as pylab
    #forces plots to appear in the ipython notebook

# ## Variables to alter (if someone else is making changes for me)
#Note: all numerical values MUST be integers
# Out:
# 3.6.7 (default, Feb 28 2019, 07:28:18) [MSC v.1900 64 bit (AMD64)]
# 2019-05-22 11:40:31.936670

# %%
numOfTrajectories = int(2500) #Number of trajectories per half wing stroke spray
shift = int(0) #This is to increase the file number as appropriate
FullRuns = int(1) #Number of full runs (MUST be >= 1)
treatment = 'fa' #Fully-actuated (fa), Under-actuated (ua), 
                  #Under-actuated AND shifted (us)

# ## Variable setup 
#(note, all are scalar values)

LengthScaleFactor = 1 #This will multiply all linear scales of the model
    #appropriately to modify the size of the model.
LengthExtend = 0 #This will lengthen the difference between the two masses.

L1 = LengthScaleFactor*0.908 #Length from the thorax-abdomen joint to 
    #the center of the head-thorax mass in cm.
    
if treatment == 'us':
    #If we do not want the L3 off the m1 center of mass:
    L3 = LengthScaleFactor*0.75 #Length from the thorax-abdomen joint to the 
                #aerodynamic force vector in cm    
else:
    #If we DO want L3 aligned with the center of mass (a.k.a. for 'ua' and 'fa'):
    L3 = L1 #Length from the thorax-abdomen joint to the aerodynamic force 
                #vector in cm

ahead = LengthScaleFactor*0.908 #Major axis of the head-thorax ellipsoid
    #in cm.
abutt = LengthScaleFactor*1.7475 #Major axis of the abdomen ellipsoid
    #in cm.
bhead = LengthScaleFactor*0.507 #Minor axis of the head-thorax ellipsoid
    #in cm.
bbutt = LengthScaleFactor*0.1295 #Minor axis of the abdomen ellipsoid
    #in cm.

L_petiole = LengthExtend*(2*(ahead+abutt)) #Length of petiole extension as a 
    #percentage of body length.
L2 = abutt + L_petiole #Length from the thorax-abdomen 
    #joint to the center of the abdomen mass in cm

K = LengthScaleFactor*29.3  #K is the torsional spring constant of 
    #the thorax-petiole joint in (cm^2)*g/(rad*(s^2))
c = LengthScaleFactor*14075.8 #c is the torsional damping constant of 
    #the thorax-petiole joint in (cm^2)*g/s
rho = 1.0 #The density of the insect in g/(cm^3)
rhoA = 1.18*10**(-3) #The density of the air in g/(cm^3)
muA = 1.86*10**(-4) #The dynamic viscosity of air at 27C in in g/(cm*s)
g = 980.0 #g is the acceleration due to gravity in cm/(s^2)

# %%
#  Filename suffix loop
point = 'p'
LSFtext = '_LSF_'
LEtext = '_LE_'
dotMATSuffix = '.mat'

if LengthScaleFactor >= 1:
    if LengthExtend < 1 and LengthExtend > 0:
        LSF_val = str(int(LengthScaleFactor))
        LE_val = str(int(10*LengthExtend))
        suffix = (treatment + LSFtext + LSF_val + LEtext + point + LE_val 
                  + dotMATSuffix)
    else:
        LSF_val = str(int(LengthScaleFactor))
        LE_val = str(int(LengthExtend))
        suffix = (treatment + LSFtext + LSF_val + LEtext + LE_val 
                  + dotMATSuffix)
    #End of first sub-IF statement
else: 
    if LengthExtend < 1 and LengthExtend > 0:
        LSF_val = str(int(10*LengthScaleFactor))
        LE_val = str(int(10*LengthExtend))
        suffix = (treatment + LSFtext + point + LSF_val + LEtext + point 
                  + LE_val + dotMATSuffix)
    else: 
        LSF_val = str(int(10*LengthScaleFactor))
        LE_val = str(int(LengthExtend))
        suffix = (treatment + LSFtext + point + LSF_val + LEtext + LE_val 
                  + dotMATSuffix)
    #End of second sub-IF statement
#End of filename suffix IF statement

print(suffix)
# Out:
# fa_LSF_1_LE_0.mat

# %%
#  More variables NOT to alter
halfwingStrokes = int(501) #Originally 500, but we need an extra half wing
    #stroke for the formal MPC.
hwbf = int(50) #wing beat frequency of the insect in Hz
timestep = int(100) #The number of timesteps we will use when interpolating
                #DO NOT CHANGE TIMESTEP SIZE
kk = int(0) #Overall counter of runs. DO NOT RESET!
i_overall = int(0) #Overall counter of runs. DO NOT RESET!
kkskip = int(1) #Overall counter OF SKIPS. Do not reset.
nn = int(1) #Counter of full runs. Do not reset!
MaxWorkers = multiprocessing.cpu_count() #Number of workers for 
        #parallel computing. Do not reset!
RecedeFrac = 0.25 #Must be a value between 0 and 1.
                #This governs how far back the goal is shifted from the
                #original goal.
goal_index = np.arange(timestep-1,(timestep*halfwingStrokes),(RecedeFrac*100))
    #Indices for the goal (without having to calculate it every loop)
    #Note: -1 is included to account for Python's annoying indexing.

#Defining the time duration of the simulations within the parallelized loop
ti = 0.0  # initial time in seconds
tf = 0.02  # final time in seconds
t_spray = np.linspace(ti, tf, timestep, endpoint = True);
#t_spray = np.linspace(ti, tf, 5, endpoint = True)

print('Number of max workers is: ', MaxWorkers)

# ## Time vector
Tstore = np.linspace(0,((1/hwbf)*halfwingStrokes),(timestep*halfwingStrokes)).T
#savemat('Tstore_MPC_hws_sp.mat', {'Tstore': Tstore}) #UNMUTE WHEN YOU WANT TO SAVE THE DATA

# ## Relevant to cost function
#Goal criteria
x_g = 0 #in cm
theta_g = np.pi/4 #in radians

xdot_g = 0 #in cm/s
thetadot_g = 0 #in radians/s

#Create the sum of primes signal
signal_amp = 5 #in cm
prime_f = np.array([0.2, 0.3, 0.5, 0.7, 1.1, 1.7, 2.9, 4.3, 7.9, 13.7, 19.9]) #in Hz
prime_a = (signal_amp/(2*np.pi*prime_f))*(2*np.pi*prime_f[0]) #in cm

#y-motion goal criteria (for the cost function)
y_g = (prime_a[0]*np.sin(2*np.pi*prime_f[0]*Tstore)
+prime_a[1]*np.sin(2*np.pi*prime_f[1]*Tstore)
+prime_a[2]*np.sin(2*np.pi*prime_f[2]*Tstore)
+prime_a[3]*np.sin(2*np.pi*prime_f[3]*Tstore)
+prime_a[4]*np.sin(2*np.pi*prime_f[4]*Tstore)
+prime_a[5]*np.sin(2*np.pi*prime_f[5]*Tstore)
+prime_a[6]*np.sin(2*np.pi*prime_f[6]*Tstore)
+prime_a[7]*np.sin(2*np.pi*prime_f[7]*Tstore)
+prime_a[8]*np.sin(2*np.pi*prime_f[8]*Tstore)
+prime_a[9]*np.sin(2*np.pi*prime_f[9]*Tstore)
+prime_a[10]*np.sin(2*np.pi*prime_f[10]*Tstore)) #in cm
    
#ydot-motion goal criteria (for the cost function)    
ydot_g = (2*np.pi*prime_a[0]*prime_f[0]*np.cos(2*np.pi*prime_f[0]*Tstore)
+2*np.pi*prime_a[1]*prime_f[1]*np.cos(2*np.pi*prime_f[1]*Tstore)
+2*np.pi*prime_a[2]*prime_f[2]*np.cos(2*np.pi*prime_f[2]*Tstore)
+2*np.pi*prime_a[3]*prime_f[3]*np.cos(2*np.pi*prime_f[3]*Tstore)
+2*np.pi*prime_a[4]*prime_f[4]*np.cos(2*np.pi*prime_f[4]*Tstore)
+2*np.pi*prime_a[5]*prime_f[5]*np.cos(2*np.pi*prime_f[5]*Tstore)
+2*np.pi*prime_a[6]*prime_f[6]*np.cos(2*np.pi*prime_f[6]*Tstore)
+2*np.pi*prime_a[7]*prime_f[7]*np.cos(2*np.pi*prime_f[7]*Tstore)
+2*np.pi*prime_a[8]*prime_f[8]*np.cos(2*np.pi*prime_f[8]*Tstore)
+2*np.pi*prime_a[9]*prime_f[9]*np.cos(2*np.pi*prime_f[9]*Tstore)
+2*np.pi*prime_a[10]*prime_f[10]*np.cos(2*np.pi*prime_f[10]*Tstore))
        #in cm/s

#Weighting coefficients (AS OF 2019/05/10)
#c1 = x,    c2 = y,      c3 = theta,  c4 = xdot,   c5 = ydot,   c6 = thetadot
c1 = 10**9; c2 = 10**10; c3 = 10**10; c4 = 10**-5; c5 = 10**-5; c6 = 10**8;
    #Reminder: Abdominal motion is NOT penalized. The question is centered 
    #around if the abdomen contributes to movement control, and if so, to what 
    #degree?
    
    #NOTE: IN MATLAB, the order of the coefficients was:
    #c1 = xdot, c2 = ydot, c3 = thetadot, c4 = x, c5 = y, c6 = theta

#Pack costCoefficients
costCoeff = np.array([c1, c2, c3, c4, c5, c6])
# Out:
# Number of max workers is:  12

# %%
# ## Initial conditions
            #q0 = [x, y, theta, phi, xdot, ydot, thetadot, phidot]
q0_og = np.array([0.0, 0.0, theta_g, (theta_g + np.pi), 10**-4, 10**-4, 0.0, 0.0])
q0 = q0_og #The initial conditions will be reset with each half wing stroke, 
            #but for now, we'll set this to the og.

betaR = q0_og[3] - q0_og[2] - np.pi #This is the resting configuration of our 
    #torsional spring(s) = Initial abdomen angle - initial head angle - pi
tsExp = int(1) #This is the torsional spring exponent. MUST be an odd number.
    
# ## Calculated inertial properies of the simulated insect
m1 = rho*(4/3)*np.pi*(bhead**2)*ahead #m1 is the mass of the head-thorax
m2 = rho*(4/3)*np.pi*(bbutt**2)*abutt #m2 is the mass of the abdomen 
                #(petiole + gaster)
echead = ahead/bhead #Eccentricity of head-thorax (unitless)
ecbutt = abutt/bbutt #Eccentricity of gaster (unitless)
I1 = (1/5)*m1*(bhead**2)*(1 + echead**2) #Moment of inertia of the 
                #head-thorax
    #The issue corrected on 1/31/19
    #Recall the parallel axis theorem: I = I_centerOfMass + m*(d^2)
    #Where m is the mass of the object, and d is the perpendicular distance
        #between the axis of rotation and the object.
I2 = (1/5)*m2*(bbutt**2)*(1 + ecbutt**2) + (m2*L_petiole**2) #Moment of 
                #inertia of the abdomen (in grams*(cm^2))
                
S_head = np.pi*(bhead**2) #This is the surface area of the object 
                #experiencing drag. In this case, it is modeled as a sphere.
S_butt = np.pi*(bbutt**2) #This is the surface area of the object 
                #experiencing drag. In this case, it is modeled as a sphere.

# %%
# ## Define global variables
globalDict = OrderedDict({"L1": L1, "L2": L2, "L3": L3, "L_petiole": L_petiole, 
              "ahead": ahead, "abutt": abutt, "bhead": bhead, "bbutt": bbutt,
              "K": K, "c": c, "rho": rho, "rhoA": rhoA, "muA": muA, "g": g,
              "m1": m1, "m2": m2, "echead": echead, "ecbutt": ecbutt, "I1": I1,
              "I2": I2, "S_head": S_head, "S_butt": S_butt, "betaR": betaR, 
              "tsExp": tsExp})

# Convert the dictionary to a list. Apparently @jit needs arrays or lists
globalList = [v_uni for v_uni in globalDict.values()]

# ## Prescribe the storage data
#xx_og = np.zeros((timestep,len(q0_og))); #This will be the vector containing 
#                                        #the state variables in the 
#                                        #parellelized loop.
#xx = xx_og; #The vector containing the state variables will be reset with each 
#            #half wing stroke, but for now, we'll set this to the og.
# tt = np.linspace(0,(1/hwbf),timestep); #This will be the time vector in the 
                                #parallelized loop for interpolation reasons.
#PartPath = ([None]*int(numOfTrajectories)); #This creates the number of 
                                       #partial paths necessary for the 
                                       #receding horizon
numOfPartialPaths = int((halfwingStrokes-1)*(1/RecedeFrac)) #An integer value 
                                            #of the number of partial paths
pre_Winstore = ([None]*numOfPartialPaths)

# %%
numOfPartialPaths
# Out:
# 2000

# %%
F_array = 44300*np.random.rand(numOfTrajectories)*(LengthScaleFactor**3)
#F is a proxy for the magnitude of the aerodynamic vector in g*cm/(s^2)

#alpha: the direction of the applied force
alpha_array = 2*np.pi*np.random.rand(numOfTrajectories)
#alpha is the angle of the aerodynamic vector with respect to 
#the head-thorax mid-line in radians

#tau0: The magnitude (and direction) of the applied abdominal torque
tau0_array = (100000*10*(2*(np.random.rand(numOfTrajectories)-0.5))*(LengthScaleFactor**4))
#The applied abdominal torque in g*(cm^2)/(s^2)

tau_w_array = (100000*(2*(np.random.rand(numOfTrajectories)-0.5))*(LengthScaleFactor**4))

#Define the goal criteria for y and ydot BEFORE the parallelized loop
i = 1
y_g_thisPartPath = y_g[int(goal_index[i])]; #in cm
ydot_g_thisPartPath = ydot_g[int(goal_index[i])] #in cm/s

#Pack goal criteria for this particular half wing stroke
goalCriteria = np.array([x_g, y_g_thisPartPath, theta_g, xdot_g, 
                         ydot_g_thisPartPath, thetadot_g])

# %%
f = multibodyDynamics_12h.generateSimulations(simNum = 1, t_spray = t_spray, 
                                     q0 = q0, 
                                     F_array = F_array, 
                                     alpha_array = alpha_array, 
                                     tau0_array = tau0_array, 
                                     tau_w_array = tau_w_array, 
                                     timestep = timestep,
                                     RecedeFrac = RecedeFrac,
                                     costCoeff = costCoeff,
                                     goalCriteria = goalCriteria,
                                     globalList = globalList)

# %%
multibodyDynamics_12h.myODE_5.inspect_types()
# Out:
# myODE_5 (array(float64, 1d, C), float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, float64, int64)
# --------------------------------------------------------------------------------
# # File: C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py
# # --- LINE 6 ---
# # label 0
#
# @jit(cache = True)
#
# # --- LINE 7 ---
#
# def myODE_5(Q, t_spray, F, alpha, tau0, tau_w, L1, L2, L3, L_petiole, ahead,
#
#             # --- LINE 8 ---
#
#             abutt, bhead, bbutt, K, c, rho, rhoA, muA, g, m1, m2, echead,
#
#             # --- LINE 9 ---
#
#             ecbutt, I1, I2, S_head, S_butt, betaR, tsExp):
#
#             # --- LINE 10 ---
#
#             #def myODE_5(Q,t, par, F, alpha, tau0, tau_w):
#
#             # --- LINE 11 ---
#
#             #Unpack the state vector (THE ORDER MATTERS)
#
#     # --- LINE 12 ---
#     #   Q = arg(0, name=Q)  :: pyobject
#     #   t_spray = arg(1, name=t_spray)  :: pyobject
#     #   del t_spray
#     #   F = arg(2, name=F)  :: pyobject
#     #   alpha = arg(3, name=alpha)  :: pyobject
#     #   tau0 = arg(4, name=tau0)  :: pyobject
#     #   tau_w = arg(5, name=tau_w)  :: pyobject
#     #   L1 = arg(6, name=L1)  :: pyobject
#     #   L2 = arg(7, name=L2)  :: pyobject
#     #   L3 = arg(8, name=L3)  :: pyobject
#     #   L_petiole = arg(9, name=L_petiole)  :: pyobject
#     #   del L_petiole
#     #   ahead = arg(10, name=ahead)  :: pyobject
#     #   del ahead
#     #   abutt = arg(11, name=abutt)  :: pyobject
#     #   del abutt
#     #   bhead = arg(12, name=bhead)  :: pyobject
#     #   bbutt = arg(13, name=bbutt)  :: pyobject
#     #   K = arg(14, name=K)  :: pyobject
#     #   c = arg(15, name=c)  :: pyobject
#     #   rho = arg(16, name=rho)  :: pyobject
#     #   del rho
#     #   rhoA = arg(17, name=rhoA)  :: pyobject
#     #   muA = arg(18, name=muA)  :: pyobject
#     #   g = arg(19, name=g)  :: pyobject
#     #   m1 = arg(20, name=m1)  :: pyobject
#     #   m2 = arg(21, name=m2)  :: pyobject
#     #   echead = arg(22, name=echead)  :: pyobject
#     #   del echead
#     #   ecbutt = arg(23, name=ecbutt)  :: pyobject
#     #   del ecbutt
#     #   I1 = arg(24, name=I1)  :: pyobject
#     #   I2 = arg(25, name=I2)  :: pyobject
#     #   S_head = arg(26, name=S_head)  :: pyobject
#     #   S_butt = arg(27, name=S_butt)  :: pyobject
#     #   betaR = arg(28, name=betaR)  :: pyobject
#     #   tsExp = arg(29, name=tsExp)  :: pyobject
#     #   $0.10 = exhaust_iter(value=Q, count=8)  :: pyobject
#     #   del Q
#     #   $0.2 = static_getitem(value=$0.10, index=0, index_var=None)  :: pyobject
#     #   $0.3 = static_getitem(value=$0.10, index=1, index_var=None)  :: pyobject
#     #   $0.4 = static_getitem(value=$0.10, index=2, index_var=None)  :: pyobject
#     #   $0.5 = static_getitem(value=$0.10, index=3, index_var=None)  :: pyobject
#     #   $0.6 = static_getitem(value=$0.10, index=4, index_var=None)  :: pyobject
#     #   $0.7 = static_getitem(value=$0.10, index=5, index_var=None)  :: pyobject
#     #   $0.8 = static_getitem(value=$0.10, index=6, index_var=None)  :: pyobject
#     #   $0.9 = static_getitem(value=$0.10, index=7, index_var=None)  :: pyobject
#     #   del $0.10
#     #   x = $0.2  :: pyobject
#     #   del x
#     #   del $0.2
#     #   y = $0.3  :: pyobject
#     #   del y
#     #   del $0.3
#     #   theta = $0.4  :: pyobject
#     #   del $0.4
#     #   phi = $0.5  :: pyobject
#     #   del $0.5
#     #   xd = $0.6  :: pyobject
#     #   del $0.6
#     #   yd = $0.7  :: pyobject
#     #   del $0.7
#     #   thetad = $0.8  :: pyobject
#     #   del $0.8
#     #   phid = $0.9  :: pyobject
#     #   del $0.9
#
#     x, y, theta, phi, xd, yd, thetad, phid = Q
#
# # --- LINE 13 ---
#
#
#
#     # --- LINE 14 ---
#
#     #Reynolds number calculation:
#
#     # --- LINE 15 ---
#     #   $0.12 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.13 = getattr(value=$0.12, attr=sqrt)  :: pyobject
#     #   del $0.12
#     #   $const0.15 = const(int, 2)  :: pyobject
#     #   $0.16 = xd ** $const0.15  :: pyobject
#     #   del $const0.15
#     #   $const0.18 = const(int, 2)  :: pyobject
#     #   $0.19 = yd ** $const0.18  :: pyobject
#     #   del $const0.18
#     #   $0.20 = $0.16 + $0.19  :: pyobject
#     #   del $0.19
#     #   del $0.16
#     #   $0.21 = call $0.13($0.20, func=$0.13, args=[Var($0.20, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (15))], kws=(), vararg=None)  :: pyobject
#     #   del $0.20
#     #   del $0.13
#     #   $0.22 = rhoA * $0.21  :: pyobject
#     #   del $0.21
#     #   $const0.23 = const(int, 2)  :: pyobject
#     #   $0.25 = $const0.23 * bhead  :: pyobject
#     #   del bhead
#     #   del $const0.23
#     #   $0.26 = $0.22 * $0.25  :: pyobject
#     #   del $0.25
#     #   del $0.22
#     #   $0.28 = $0.26 / muA  :: pyobject
#     #   del $0.26
#     #   Re_head = $0.28  :: pyobject
#     #   del $0.28
#
#     Re_head = rhoA*(np.sqrt((xd**2)+(yd**2)))*(2*bhead)/muA #dimensionless number
#
#     # --- LINE 16 ---
#     #   $0.30 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.31 = getattr(value=$0.30, attr=sqrt)  :: pyobject
#     #   del $0.30
#     #   $const0.33 = const(int, 2)  :: pyobject
#     #   $0.34 = xd ** $const0.33  :: pyobject
#     #   del $const0.33
#     #   $const0.36 = const(int, 2)  :: pyobject
#     #   $0.37 = yd ** $const0.36  :: pyobject
#     #   del $const0.36
#     #   $0.38 = $0.34 + $0.37  :: pyobject
#     #   del $0.37
#     #   del $0.34
#     #   $0.39 = call $0.31($0.38, func=$0.31, args=[Var($0.38, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (16))], kws=(), vararg=None)  :: pyobject
#     #   del $0.38
#     #   del $0.31
#     #   $0.40 = rhoA * $0.39  :: pyobject
#     #   del $0.39
#     #   $const0.41 = const(int, 2)  :: pyobject
#     #   $0.43 = $const0.41 * bbutt  :: pyobject
#     #   del bbutt
#     #   del $const0.41
#     #   $0.44 = $0.40 * $0.43  :: pyobject
#     #   del $0.43
#     #   del $0.40
#     #   $0.46 = $0.44 / muA  :: pyobject
#     #   del muA
#     #   del $0.44
#     #   Re_butt = $0.46  :: pyobject
#     #   del $0.46
#
#     Re_butt = rhoA*(np.sqrt((xd**2)+(yd**2)))*(2*bbutt)/muA #dimensionless number
#
# # --- LINE 17 ---
#
#
#
#     # --- LINE 18 ---
#
#     #Coefficient of drag stuff:
#
#     # --- LINE 19 ---
#     #   $const0.47 = const(int, 24)  :: pyobject
#     #   $0.48 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.49 = getattr(value=$0.48, attr=abs)  :: pyobject
#     #   del $0.48
#     #   $0.51 = call $0.49(Re_head, func=$0.49, args=[Var(Re_head, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (15))], kws=(), vararg=None)  :: pyobject
#     #   del $0.49
#     #   $0.52 = $const0.47 / $0.51  :: pyobject
#     #   del $const0.47
#     #   del $0.51
#     #   $const0.53 = const(int, 6)  :: pyobject
#     #   $const0.54 = const(int, 1)  :: pyobject
#     #   $0.55 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.56 = getattr(value=$0.55, attr=sqrt)  :: pyobject
#     #   del $0.55
#     #   $0.57 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.58 = getattr(value=$0.57, attr=abs)  :: pyobject
#     #   del $0.57
#     #   $0.60 = call $0.58(Re_head, func=$0.58, args=[Var(Re_head, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (15))], kws=(), vararg=None)  :: pyobject
#     #   del Re_head
#     #   del $0.58
#     #   $0.61 = call $0.56($0.60, func=$0.56, args=[Var($0.60, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (19))], kws=(), vararg=None)  :: pyobject
#     #   del $0.60
#     #   del $0.56
#     #   $0.62 = $const0.54 + $0.61  :: pyobject
#     #   del $const0.54
#     #   del $0.61
#     #   $0.63 = $const0.53 / $0.62  :: pyobject
#     #   del $const0.53
#     #   del $0.62
#     #   $0.64 = $0.52 + $0.63  :: pyobject
#     #   del $0.63
#     #   del $0.52
#     #   $const0.65 = const(float, 0.4)  :: pyobject
#     #   $0.66 = $0.64 + $const0.65  :: pyobject
#     #   del $const0.65
#     #   del $0.64
#     #   Cd_head = $0.66  :: pyobject
#     #   del $0.66
#
#     Cd_head = 24/np.abs(Re_head) + 6/(1 + np.sqrt(np.abs(Re_head))) + 0.4
#
#     # --- LINE 20 ---
#     #   $const0.67 = const(int, 24)  :: pyobject
#     #   $0.68 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.69 = getattr(value=$0.68, attr=abs)  :: pyobject
#     #   del $0.68
#     #   $0.71 = call $0.69(Re_butt, func=$0.69, args=[Var(Re_butt, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (16))], kws=(), vararg=None)  :: pyobject
#     #   del $0.69
#     #   $0.72 = $const0.67 / $0.71  :: pyobject
#     #   del $const0.67
#     #   del $0.71
#     #   $const0.73 = const(int, 6)  :: pyobject
#     #   $const0.74 = const(int, 1)  :: pyobject
#     #   $0.75 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.76 = getattr(value=$0.75, attr=sqrt)  :: pyobject
#     #   del $0.75
#     #   $0.77 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.78 = getattr(value=$0.77, attr=abs)  :: pyobject
#     #   del $0.77
#     #   $0.80 = call $0.78(Re_butt, func=$0.78, args=[Var(Re_butt, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (16))], kws=(), vararg=None)  :: pyobject
#     #   del Re_butt
#     #   del $0.78
#     #   $0.81 = call $0.76($0.80, func=$0.76, args=[Var($0.80, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (20))], kws=(), vararg=None)  :: pyobject
#     #   del $0.80
#     #   del $0.76
#     #   $0.82 = $const0.74 + $0.81  :: pyobject
#     #   del $const0.74
#     #   del $0.81
#     #   $0.83 = $const0.73 / $0.82  :: pyobject
#     #   del $const0.73
#     #   del $0.82
#     #   $0.84 = $0.72 + $0.83  :: pyobject
#     #   del $0.83
#     #   del $0.72
#     #   $const0.85 = const(float, 0.4)  :: pyobject
#     #   $0.86 = $0.84 + $const0.85  :: pyobject
#     #   del $const0.85
#     #   del $0.84
#     #   Cd_butt = $0.86  :: pyobject
#     #   del $0.86
#
#     Cd_butt = 24/np.abs(Re_butt) + 6/(1 + np.sqrt(np.abs(Re_butt))) + 0.4
#
# # --- LINE 21 ---
#
#
#
#     # --- LINE 22 ---
#
#     #These are the coefficients for our acceleration equations imported from Mathematica
#
#         # --- LINE 23 ---
#
#         #(and MATLAB). Careful, this'll get messy.
#
#     # --- LINE 24 ---
#     #   $0.89 = m1 + m2  :: pyobject
#     #   h1 = $0.89  :: pyobject
#     #   del $0.89
#
#     h1 = m1 + m2
#
#     # --- LINE 25 ---
#     #   $const0.90 = const(int, -1)  :: pyobject
#     #   $0.92 = $const0.90 * L1  :: pyobject
#     #   del $const0.90
#     #   $0.94 = $0.92 * m1  :: pyobject
#     #   del $0.92
#     #   $0.95 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.96 = getattr(value=$0.95, attr=sin)  :: pyobject
#     #   del $0.95
#     #   $0.98 = call $0.96(theta, func=$0.96, args=[Var(theta, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#     #   del $0.96
#     #   $0.99 = $0.94 * $0.98  :: pyobject
#     #   del $0.98
#     #   del $0.94
#     #   h2 = $0.99  :: pyobject
#     #   del $0.99
#
#     h2 = (-1)*L1*m1*np.sin(theta)
#
#     # --- LINE 26 ---
#     #   $const0.100 = const(int, -1)  :: pyobject
#     #   $0.102 = $const0.100 * L2  :: pyobject
#     #   del $const0.100
#     #   $0.104 = $0.102 * m2  :: pyobject
#     #   del $0.102
#     #   $0.105 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.106 = getattr(value=$0.105, attr=sin)  :: pyobject
#     #   del $0.105
#     #   $0.108 = call $0.106(phi, func=$0.106, args=[Var(phi, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#     #   del $0.106
#     #   $0.109 = $0.104 * $0.108  :: pyobject
#     #   del $0.108
#     #   del $0.104
#     #   h3 = $0.109  :: pyobject
#     #   del $0.109
#
#     h3 = (-1)*L2*m2*np.sin(phi)
#
#     # --- LINE 27 ---
#     #   $0.112 = L1 * m1  :: pyobject
#     #   $0.113 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.114 = getattr(value=$0.113, attr=cos)  :: pyobject
#     #   del $0.113
#     #   $0.116 = call $0.114(theta, func=$0.114, args=[Var(theta, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#     #   del $0.114
#     #   $0.117 = $0.112 * $0.116  :: pyobject
#     #   del $0.116
#     #   del $0.112
#     #   h4 = $0.117  :: pyobject
#     #   del $0.117
#
#     h4 = L1*m1*np.cos(theta)
#
#     # --- LINE 28 ---
#     #   $0.120 = L2 * m2  :: pyobject
#     #   $0.121 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.122 = getattr(value=$0.121, attr=cos)  :: pyobject
#     #   del $0.121
#     #   $0.124 = call $0.122(phi, func=$0.122, args=[Var(phi, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#     #   del $0.122
#     #   $0.125 = $0.120 * $0.124  :: pyobject
#     #   del $0.124
#     #   del $0.120
#     #   h5 = $0.125  :: pyobject
#     #   del $0.125
#
#     h5 = L2*m2*np.cos(phi)
#
#     # --- LINE 29 ---
#
#     h6 = ((-1)*F*np.cos(alpha+theta)+(1/2)*Cd_butt*rhoA*S_butt*np.abs(xd)*xd
#
#           # --- LINE 30 ---
#
#           +(1/2)*Cd_head*rhoA*S_head*np.abs(xd)*xd+(-1)*L1*m1*np.cos(theta)*thetad**2
#
#           # --- LINE 31 ---
#           #   $const0.126 = const(int, -1)  :: pyobject
#           #   $0.128 = $const0.126 * F  :: pyobject
#           #   del $const0.126
#           #   $0.129 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.130 = getattr(value=$0.129, attr=cos)  :: pyobject
#           #   del $0.129
#           #   $0.133 = alpha + theta  :: pyobject
#           #   $0.134 = call $0.130($0.133, func=$0.130, args=[Var($0.133, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (31))], kws=(), vararg=None)  :: pyobject
#           #   del $0.133
#           #   del $0.130
#           #   $0.135 = $0.128 * $0.134  :: pyobject
#           #   del $0.134
#           #   del $0.128
#           #   $const0.136 = const(float, 0.5)  :: pyobject
#           #   $0.138 = $const0.136 * Cd_butt  :: pyobject
#           #   del $const0.136
#           #   $0.140 = $0.138 * rhoA  :: pyobject
#           #   del $0.138
#           #   $0.142 = $0.140 * S_butt  :: pyobject
#           #   del $0.140
#           #   $0.143 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.144 = getattr(value=$0.143, attr=abs)  :: pyobject
#           #   del $0.143
#           #   $0.146 = call $0.144(xd, func=$0.144, args=[Var(xd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.144
#           #   $0.147 = $0.142 * $0.146  :: pyobject
#           #   del $0.146
#           #   del $0.142
#           #   $0.149 = $0.147 * xd  :: pyobject
#           #   del $0.147
#           #   $0.150 = $0.135 + $0.149  :: pyobject
#           #   del $0.149
#           #   del $0.135
#           #   $const0.151 = const(float, 0.5)  :: pyobject
#           #   $0.153 = $const0.151 * Cd_head  :: pyobject
#           #   del $const0.151
#           #   $0.155 = $0.153 * rhoA  :: pyobject
#           #   del $0.153
#           #   $0.157 = $0.155 * S_head  :: pyobject
#           #   del $0.155
#           #   $0.158 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.159 = getattr(value=$0.158, attr=abs)  :: pyobject
#           #   del $0.158
#           #   $0.161 = call $0.159(xd, func=$0.159, args=[Var(xd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.159
#           #   $0.162 = $0.157 * $0.161  :: pyobject
#           #   del $0.161
#           #   del $0.157
#           #   $0.164 = $0.162 * xd  :: pyobject
#           #   del $0.162
#           #   $0.165 = $0.150 + $0.164  :: pyobject
#           #   del $0.164
#           #   del $0.150
#           #   $const0.166 = const(int, -1)  :: pyobject
#           #   $0.168 = $const0.166 * L1  :: pyobject
#           #   del $const0.166
#           #   $0.170 = $0.168 * m1  :: pyobject
#           #   del $0.168
#           #   $0.171 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.172 = getattr(value=$0.171, attr=cos)  :: pyobject
#           #   del $0.171
#           #   $0.174 = call $0.172(theta, func=$0.172, args=[Var(theta, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.172
#           #   $0.175 = $0.170 * $0.174  :: pyobject
#           #   del $0.174
#           #   del $0.170
#           #   $const0.177 = const(int, 2)  :: pyobject
#           #   $0.178 = thetad ** $const0.177  :: pyobject
#           #   del $const0.177
#           #   $0.179 = $0.175 * $0.178  :: pyobject
#           #   del $0.178
#           #   del $0.175
#           #   $0.180 = $0.165 + $0.179  :: pyobject
#           #   del $0.179
#           #   del $0.165
#           #   $const0.181 = const(int, -1)  :: pyobject
#           #   $0.183 = $const0.181 * L2  :: pyobject
#           #   del $const0.181
#           #   $0.185 = $0.183 * m2  :: pyobject
#           #   del $0.183
#           #   $0.186 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.187 = getattr(value=$0.186, attr=cos)  :: pyobject
#           #   del $0.186
#           #   $0.189 = call $0.187(phi, func=$0.187, args=[Var(phi, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.187
#           #   $0.190 = $0.185 * $0.189  :: pyobject
#           #   del $0.189
#           #   del $0.185
#           #   $const0.192 = const(int, 2)  :: pyobject
#           #   $0.193 = phid ** $const0.192  :: pyobject
#           #   del $const0.192
#           #   $0.194 = $0.190 * $0.193  :: pyobject
#           #   del $0.193
#           #   del $0.190
#           #   $0.195 = $0.180 + $0.194  :: pyobject
#           #   del $0.194
#           #   del $0.180
#           #   h6 = $0.195  :: pyobject
#           #   del $0.195
#
#           +(-1)*L2*m2*np.cos(phi)*phid**2)
#
#     # --- LINE 32 ---
#
#     h7 = (g*(m1+m2)+(1/2)*Cd_butt*rhoA*S_butt*np.abs(yd)*yd+(1/2)*Cd_head*rhoA
#
#           # --- LINE 33 ---
#
#           *S_head*np.abs(yd)*yd+(-1)*L1*m1*thetad**2*np.sin(theta)
#
#           # --- LINE 34 ---
#           #   $0.199 = m1 + m2  :: pyobject
#           #   $0.200 = g * $0.199  :: pyobject
#           #   del $0.199
#           #   $const0.201 = const(float, 0.5)  :: pyobject
#           #   $0.203 = $const0.201 * Cd_butt  :: pyobject
#           #   del Cd_butt
#           #   del $const0.201
#           #   $0.205 = $0.203 * rhoA  :: pyobject
#           #   del $0.203
#           #   $0.207 = $0.205 * S_butt  :: pyobject
#           #   del S_butt
#           #   del $0.205
#           #   $0.208 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.209 = getattr(value=$0.208, attr=abs)  :: pyobject
#           #   del $0.208
#           #   $0.211 = call $0.209(yd, func=$0.209, args=[Var(yd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.209
#           #   $0.212 = $0.207 * $0.211  :: pyobject
#           #   del $0.211
#           #   del $0.207
#           #   $0.214 = $0.212 * yd  :: pyobject
#           #   del $0.212
#           #   $0.215 = $0.200 + $0.214  :: pyobject
#           #   del $0.214
#           #   del $0.200
#           #   $const0.216 = const(float, 0.5)  :: pyobject
#           #   $0.218 = $const0.216 * Cd_head  :: pyobject
#           #   del Cd_head
#           #   del $const0.216
#           #   $0.220 = $0.218 * rhoA  :: pyobject
#           #   del rhoA
#           #   del $0.218
#           #   $0.222 = $0.220 * S_head  :: pyobject
#           #   del S_head
#           #   del $0.220
#           #   $0.223 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.224 = getattr(value=$0.223, attr=abs)  :: pyobject
#           #   del $0.223
#           #   $0.226 = call $0.224(yd, func=$0.224, args=[Var(yd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.224
#           #   $0.227 = $0.222 * $0.226  :: pyobject
#           #   del $0.226
#           #   del $0.222
#           #   $0.229 = $0.227 * yd  :: pyobject
#           #   del $0.227
#           #   $0.230 = $0.215 + $0.229  :: pyobject
#           #   del $0.229
#           #   del $0.215
#           #   $const0.231 = const(int, -1)  :: pyobject
#           #   $0.233 = $const0.231 * L1  :: pyobject
#           #   del $const0.231
#           #   $0.235 = $0.233 * m1  :: pyobject
#           #   del $0.233
#           #   $const0.237 = const(int, 2)  :: pyobject
#           #   $0.238 = thetad ** $const0.237  :: pyobject
#           #   del $const0.237
#           #   $0.239 = $0.235 * $0.238  :: pyobject
#           #   del $0.238
#           #   del $0.235
#           #   $0.240 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.241 = getattr(value=$0.240, attr=sin)  :: pyobject
#           #   del $0.240
#           #   $0.243 = call $0.241(theta, func=$0.241, args=[Var(theta, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.241
#           #   $0.244 = $0.239 * $0.243  :: pyobject
#           #   del $0.243
#           #   del $0.239
#           #   $0.245 = $0.230 + $0.244  :: pyobject
#           #   del $0.244
#           #   del $0.230
#           #   $const0.246 = const(int, -1)  :: pyobject
#           #   $0.248 = $const0.246 * F  :: pyobject
#           #   del $const0.246
#           #   $0.249 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.250 = getattr(value=$0.249, attr=sin)  :: pyobject
#           #   del $0.249
#           #   $0.253 = alpha + theta  :: pyobject
#           #   $0.254 = call $0.250($0.253, func=$0.250, args=[Var($0.253, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (34))], kws=(), vararg=None)  :: pyobject
#           #   del $0.253
#           #   del $0.250
#           #   $0.255 = $0.248 * $0.254  :: pyobject
#           #   del $0.254
#           #   del $0.248
#           #   $0.256 = $0.245 + $0.255  :: pyobject
#           #   del $0.255
#           #   del $0.245
#           #   $const0.257 = const(int, -1)  :: pyobject
#           #   $0.259 = $const0.257 * L2  :: pyobject
#           #   del $const0.257
#           #   $0.261 = $0.259 * m2  :: pyobject
#           #   del $0.259
#           #   $const0.263 = const(int, 2)  :: pyobject
#           #   $0.264 = phid ** $const0.263  :: pyobject
#           #   del $const0.263
#           #   $0.265 = $0.261 * $0.264  :: pyobject
#           #   del $0.264
#           #   del $0.261
#           #   $0.266 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#           #   $0.267 = getattr(value=$0.266, attr=sin)  :: pyobject
#           #   del $0.266
#           #   $0.269 = call $0.267(phi, func=$0.267, args=[Var(phi, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#           #   del $0.267
#           #   $0.270 = $0.265 * $0.269  :: pyobject
#           #   del $0.269
#           #   del $0.265
#           #   $0.271 = $0.256 + $0.270  :: pyobject
#           #   del $0.270
#           #   del $0.256
#           #   h7 = $0.271  :: pyobject
#           #   del $0.271
#
#           +(-1)*F*np.sin(alpha+theta)+(-1)*L2*m2*phid**2*np.sin(phi))
#
#     # --- LINE 35 ---
#
#     h8 = ((-1)*tau0+g*L1*m1*np.cos(theta)+(-1)*K*(((-1)*betaR+(-1)*np.pi+
#
#            # --- LINE 36 ---
#            #   $const0.272 = const(int, -1)  :: pyobject
#            #   $0.274 = $const0.272 * tau0  :: pyobject
#            #   del $const0.272
#            #   $0.277 = g * L1  :: pyobject
#            #   $0.279 = $0.277 * m1  :: pyobject
#            #   del $0.277
#            #   $0.280 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#            #   $0.281 = getattr(value=$0.280, attr=cos)  :: pyobject
#            #   del $0.280
#            #   $0.283 = call $0.281(theta, func=$0.281, args=[Var(theta, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#            #   del $0.281
#            #   $0.284 = $0.279 * $0.283  :: pyobject
#            #   del $0.283
#            #   del $0.279
#            #   $0.285 = $0.274 + $0.284  :: pyobject
#            #   del $0.284
#            #   del $0.274
#            #   $const0.286 = const(int, -1)  :: pyobject
#            #   $0.288 = $const0.286 * K  :: pyobject
#            #   del $const0.286
#            #   $const0.289 = const(int, -1)  :: pyobject
#            #   $0.291 = $const0.289 * betaR  :: pyobject
#            #   del $const0.289
#            #   $const0.292 = const(int, -1)  :: pyobject
#            #   $0.293 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#            #   $0.294 = getattr(value=$0.293, attr=pi)  :: pyobject
#            #   del $0.293
#            #   $0.295 = $const0.292 * $0.294  :: pyobject
#            #   del $const0.292
#            #   del $0.294
#            #   $0.296 = $0.291 + $0.295  :: pyobject
#            #   del $0.295
#            #   del $0.291
#            #   $const0.297 = const(int, -1)  :: pyobject
#            #   $0.299 = $const0.297 * theta  :: pyobject
#            #   del $const0.297
#            #   $0.300 = $0.296 + $0.299  :: pyobject
#            #   del $0.299
#            #   del $0.296
#            #   $0.302 = $0.300 + phi  :: pyobject
#            #   del $0.300
#            #   $0.304 = $0.302 ** tsExp  :: pyobject
#            #   del $0.302
#            #   $0.305 = $0.288 * $0.304  :: pyobject
#            #   del $0.304
#            #   del $0.288
#            #   $0.306 = $0.285 + $0.305  :: pyobject
#            #   del $0.305
#            #   del $0.285
#            #   $const0.307 = const(int, -1)  :: pyobject
#            #   $0.309 = $const0.307 * c  :: pyobject
#            #   del $const0.307
#            #   $const0.310 = const(int, -1)  :: pyobject
#            #   $0.312 = $const0.310 * thetad  :: pyobject
#            #   del $const0.310
#            #   $0.314 = $0.312 + phid  :: pyobject
#            #   del $0.312
#            #   $0.315 = $0.309 * $0.314  :: pyobject
#            #   del $0.314
#            #   del $0.309
#            #   $0.316 = $0.306 + $0.315  :: pyobject
#            #   del $0.315
#            #   del $0.306
#            #   $const0.317 = const(int, -1)  :: pyobject
#            #   $0.319 = $const0.317 * F  :: pyobject
#            #   del F
#            #   del $const0.317
#            #   $0.321 = $0.319 * L3  :: pyobject
#            #   del L3
#            #   del $0.319
#            #   $0.322 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#            #   $0.323 = getattr(value=$0.322, attr=sin)  :: pyobject
#            #   del $0.322
#            #   $0.325 = call $0.323(alpha, func=$0.323, args=[Var(alpha, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#            #   del alpha
#            #   del $0.323
#            #   $0.326 = $0.321 * $0.325  :: pyobject
#            #   del $0.325
#            #   del $0.321
#            #   $0.327 = $0.316 + $0.326  :: pyobject
#            #   del $0.326
#            #   del $0.316
#            #   $0.329 = $0.327 - tau_w  :: pyobject
#            #   del tau_w
#            #   del $0.327
#            #   h8 = $0.329  :: pyobject
#            #   del $0.329
#
#            (-1)*theta+phi)**tsExp)+(-1)*c*((-1)*thetad+phid)+(-1)*F*L3*np.sin(alpha)-tau_w)
#
#     # --- LINE 37 ---
#
#     h9 = (tau0+g*L2*m2*np.cos(phi)+K*(((-1)*betaR+(-1)*np.pi+(-1)*theta+phi)**tsExp)
#
#     # --- LINE 38 ---
#     #   $0.333 = g * L2  :: pyobject
#     #   del g
#     #   $0.335 = $0.333 * m2  :: pyobject
#     #   del $0.333
#     #   $0.336 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.337 = getattr(value=$0.336, attr=cos)  :: pyobject
#     #   del $0.336
#     #   $0.339 = call $0.337(phi, func=$0.337, args=[Var(phi, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12))], kws=(), vararg=None)  :: pyobject
#     #   del $0.337
#     #   $0.340 = $0.335 * $0.339  :: pyobject
#     #   del $0.339
#     #   del $0.335
#     #   $0.341 = tau0 + $0.340  :: pyobject
#     #   del tau0
#     #   del $0.340
#     #   $const0.343 = const(int, -1)  :: pyobject
#     #   $0.345 = $const0.343 * betaR  :: pyobject
#     #   del betaR
#     #   del $const0.343
#     #   $const0.346 = const(int, -1)  :: pyobject
#     #   $0.347 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.348 = getattr(value=$0.347, attr=pi)  :: pyobject
#     #   del $0.347
#     #   $0.349 = $const0.346 * $0.348  :: pyobject
#     #   del $const0.346
#     #   del $0.348
#     #   $0.350 = $0.345 + $0.349  :: pyobject
#     #   del $0.349
#     #   del $0.345
#     #   $const0.351 = const(int, -1)  :: pyobject
#     #   $0.353 = $const0.351 * theta  :: pyobject
#     #   del theta
#     #   del $const0.351
#     #   $0.354 = $0.350 + $0.353  :: pyobject
#     #   del $0.353
#     #   del $0.350
#     #   $0.356 = $0.354 + phi  :: pyobject
#     #   del phi
#     #   del $0.354
#     #   $0.358 = $0.356 ** tsExp  :: pyobject
#     #   del tsExp
#     #   del $0.356
#     #   $0.359 = K * $0.358  :: pyobject
#     #   del K
#     #   del $0.358
#     #   $0.360 = $0.341 + $0.359  :: pyobject
#     #   del $0.359
#     #   del $0.341
#     #   $const0.362 = const(int, -1)  :: pyobject
#     #   $0.364 = $const0.362 * thetad  :: pyobject
#     #   del $const0.362
#     #   $0.366 = $0.364 + phid  :: pyobject
#     #   del $0.364
#     #   $0.367 = c * $0.366  :: pyobject
#     #   del c
#     #   del $0.366
#     #   $0.368 = $0.360 + $0.367  :: pyobject
#     #   del $0.367
#     #   del $0.360
#     #   h9 = $0.368  :: pyobject
#     #   del $0.368
#
#     +c*((-1)*thetad+phid))
#
# # --- LINE 39 ---
#
#
#
#     # --- LINE 40 ---
#     #   $const0.371 = const(int, 2)  :: pyobject
#     #   $0.372 = L1 ** $const0.371  :: pyobject
#     #   del L1
#     #   del $const0.371
#     #   $0.374 = $0.372 * m1  :: pyobject
#     #   del m1
#     #   del $0.372
#     #   $0.375 = I1 + $0.374  :: pyobject
#     #   del I1
#     #   del $0.374
#     #   h10 = $0.375  :: pyobject
#     #   del $0.375
#
#     h10 = I1+(L1**2)*m1
#
#     # --- LINE 41 ---
#     #   $const0.378 = const(int, 2)  :: pyobject
#     #   $0.379 = L2 ** $const0.378  :: pyobject
#     #   del L2
#     #   del $const0.378
#     #   $0.381 = $0.379 * m2  :: pyobject
#     #   del m2
#     #   del $0.379
#     #   $0.382 = I2 + $0.381  :: pyobject
#     #   del I2
#     #   del $0.381
#     #   h11 = $0.382  :: pyobject
#     #   del $0.382
#
#     h11 = I2+(L2**2)*m2
#
# # --- LINE 42 ---
#
#
#
#     # --- LINE 43 ---
#
#     #x double dot
#
#     # --- LINE 44 ---
#
#     xdd = ((-1)*(h10*h11*h1**2+(-1)*h11*h1*h2**2
#
#             # --- LINE 45 ---
#
#             +(-1)*h10*h1*h3**2+(-1)*h11*h1*h4**2+h3**2*h4**2
#
#             # --- LINE 46 ---
#             #   $const0.383 = const(int, -1)  :: pyobject
#             #   $0.386 = h10 * h11  :: pyobject
#             #   $const0.388 = const(int, 2)  :: pyobject
#             #   $0.389 = h1 ** $const0.388  :: pyobject
#             #   del $const0.388
#             #   $0.390 = $0.386 * $0.389  :: pyobject
#             #   del $0.389
#             #   del $0.386
#             #   $const0.391 = const(int, -1)  :: pyobject
#             #   $0.393 = $const0.391 * h11  :: pyobject
#             #   del $const0.391
#             #   $0.395 = $0.393 * h1  :: pyobject
#             #   del $0.393
#             #   $const0.397 = const(int, 2)  :: pyobject
#             #   $0.398 = h2 ** $const0.397  :: pyobject
#             #   del $const0.397
#             #   $0.399 = $0.395 * $0.398  :: pyobject
#             #   del $0.398
#             #   del $0.395
#             #   $0.400 = $0.390 + $0.399  :: pyobject
#             #   del $0.399
#             #   del $0.390
#             #   $const0.401 = const(int, -1)  :: pyobject
#             #   $0.403 = $const0.401 * h10  :: pyobject
#             #   del $const0.401
#             #   $0.405 = $0.403 * h1  :: pyobject
#             #   del $0.403
#             #   $const0.407 = const(int, 2)  :: pyobject
#             #   $0.408 = h3 ** $const0.407  :: pyobject
#             #   del $const0.407
#             #   $0.409 = $0.405 * $0.408  :: pyobject
#             #   del $0.408
#             #   del $0.405
#             #   $0.410 = $0.400 + $0.409  :: pyobject
#             #   del $0.409
#             #   del $0.400
#             #   $const0.411 = const(int, -1)  :: pyobject
#             #   $0.413 = $const0.411 * h11  :: pyobject
#             #   del $const0.411
#             #   $0.415 = $0.413 * h1  :: pyobject
#             #   del $0.413
#             #   $const0.417 = const(int, 2)  :: pyobject
#             #   $0.418 = h4 ** $const0.417  :: pyobject
#             #   del $const0.417
#             #   $0.419 = $0.415 * $0.418  :: pyobject
#             #   del $0.418
#             #   del $0.415
#             #   $0.420 = $0.410 + $0.419  :: pyobject
#             #   del $0.419
#             #   del $0.410
#             #   $const0.422 = const(int, 2)  :: pyobject
#             #   $0.423 = h3 ** $const0.422  :: pyobject
#             #   del $const0.422
#             #   $const0.425 = const(int, 2)  :: pyobject
#             #   $0.426 = h4 ** $const0.425  :: pyobject
#             #   del $const0.425
#             #   $0.427 = $0.423 * $0.426  :: pyobject
#             #   del $0.426
#             #   del $0.423
#             #   $0.428 = $0.420 + $0.427  :: pyobject
#             #   del $0.427
#             #   del $0.420
#             #   $const0.429 = const(int, -2)  :: pyobject
#             #   $0.431 = $const0.429 * h2  :: pyobject
#             #   del $const0.429
#             #   $0.433 = $0.431 * h3  :: pyobject
#             #   del $0.431
#             #   $0.435 = $0.433 * h4  :: pyobject
#             #   del $0.433
#             #   $0.437 = $0.435 * h5  :: pyobject
#             #   del $0.435
#             #   $0.438 = $0.428 + $0.437  :: pyobject
#             #   del $0.437
#             #   del $0.428
#             #   $const0.439 = const(int, -1)  :: pyobject
#             #   $0.441 = $const0.439 * h10  :: pyobject
#             #   del $const0.439
#             #   $0.443 = $0.441 * h1  :: pyobject
#             #   del $0.441
#             #   $const0.445 = const(int, 2)  :: pyobject
#             #   $0.446 = h5 ** $const0.445  :: pyobject
#             #   del $const0.445
#             #   $0.447 = $0.443 * $0.446  :: pyobject
#             #   del $0.446
#             #   del $0.443
#             #   $0.448 = $0.438 + $0.447  :: pyobject
#             #   del $0.447
#             #   del $0.438
#             #   $const0.450 = const(int, 2)  :: pyobject
#             #   $0.451 = h2 ** $const0.450  :: pyobject
#             #   del $const0.450
#             #   $const0.453 = const(int, 2)  :: pyobject
#             #   $0.454 = h5 ** $const0.453  :: pyobject
#             #   del $const0.453
#             #   $0.455 = $0.451 * $0.454  :: pyobject
#             #   del $0.454
#             #   del $0.451
#             #   $0.456 = $0.448 + $0.455  :: pyobject
#             #   del $0.455
#             #   del $0.448
#             #   $const0.457 = const(int, -1)  :: pyobject
#             #   $0.458 = $0.456 ** $const0.457  :: pyobject
#             #   del $const0.457
#             #   del $0.456
#             #   $0.459 = $const0.383 * $0.458  :: pyobject
#             #   del $const0.383
#             #   del $0.458
#
#             +(-2)*h2*h3*h4*h5+(-1)*h10*h1*h5**2+h2**2*h5**2)**(-1)*(h10*h11*h1*h6
#
#              # --- LINE 47 ---
#
#              +(-1)*h11*h4**2*h6+(-1)*h10*h5**2*h6+h11*h2*h4*h7+h10*h3*h5*h7
#
#              # --- LINE 48 ---
#
#              +(-1)*h11*h1*h2*h8+(-1)*h3*h4*h5*h8+h2*h5**2*h8
#
#              # --- LINE 49 ---
#              #   $0.462 = h10 * h11  :: pyobject
#              #   $0.464 = $0.462 * h1  :: pyobject
#              #   del $0.462
#              #   $0.466 = $0.464 * h6  :: pyobject
#              #   del $0.464
#              #   $const0.467 = const(int, -1)  :: pyobject
#              #   $0.469 = $const0.467 * h11  :: pyobject
#              #   del $const0.467
#              #   $const0.471 = const(int, 2)  :: pyobject
#              #   $0.472 = h4 ** $const0.471  :: pyobject
#              #   del $const0.471
#              #   $0.473 = $0.469 * $0.472  :: pyobject
#              #   del $0.472
#              #   del $0.469
#              #   $0.475 = $0.473 * h6  :: pyobject
#              #   del $0.473
#              #   $0.476 = $0.466 + $0.475  :: pyobject
#              #   del $0.475
#              #   del $0.466
#              #   $const0.477 = const(int, -1)  :: pyobject
#              #   $0.479 = $const0.477 * h10  :: pyobject
#              #   del $const0.477
#              #   $const0.481 = const(int, 2)  :: pyobject
#              #   $0.482 = h5 ** $const0.481  :: pyobject
#              #   del $const0.481
#              #   $0.483 = $0.479 * $0.482  :: pyobject
#              #   del $0.482
#              #   del $0.479
#              #   $0.485 = $0.483 * h6  :: pyobject
#              #   del $0.483
#              #   $0.486 = $0.476 + $0.485  :: pyobject
#              #   del $0.485
#              #   del $0.476
#              #   $0.489 = h11 * h2  :: pyobject
#              #   $0.491 = $0.489 * h4  :: pyobject
#              #   del $0.489
#              #   $0.493 = $0.491 * h7  :: pyobject
#              #   del $0.491
#              #   $0.494 = $0.486 + $0.493  :: pyobject
#              #   del $0.493
#              #   del $0.486
#              #   $0.497 = h10 * h3  :: pyobject
#              #   $0.499 = $0.497 * h5  :: pyobject
#              #   del $0.497
#              #   $0.501 = $0.499 * h7  :: pyobject
#              #   del $0.499
#              #   $0.502 = $0.494 + $0.501  :: pyobject
#              #   del $0.501
#              #   del $0.494
#              #   $const0.503 = const(int, -1)  :: pyobject
#              #   $0.505 = $const0.503 * h11  :: pyobject
#              #   del $const0.503
#              #   $0.507 = $0.505 * h1  :: pyobject
#              #   del $0.505
#              #   $0.509 = $0.507 * h2  :: pyobject
#              #   del $0.507
#              #   $0.511 = $0.509 * h8  :: pyobject
#              #   del $0.509
#              #   $0.512 = $0.502 + $0.511  :: pyobject
#              #   del $0.511
#              #   del $0.502
#              #   $const0.513 = const(int, -1)  :: pyobject
#              #   $0.515 = $const0.513 * h3  :: pyobject
#              #   del $const0.513
#              #   $0.517 = $0.515 * h4  :: pyobject
#              #   del $0.515
#              #   $0.519 = $0.517 * h5  :: pyobject
#              #   del $0.517
#              #   $0.521 = $0.519 * h8  :: pyobject
#              #   del $0.519
#              #   $0.522 = $0.512 + $0.521  :: pyobject
#              #   del $0.521
#              #   del $0.512
#              #   $const0.525 = const(int, 2)  :: pyobject
#              #   $0.526 = h5 ** $const0.525  :: pyobject
#              #   del $const0.525
#              #   $0.527 = h2 * $0.526  :: pyobject
#              #   del $0.526
#              #   $0.529 = $0.527 * h8  :: pyobject
#              #   del $0.527
#              #   $0.530 = $0.522 + $0.529  :: pyobject
#              #   del $0.529
#              #   del $0.522
#              #   $const0.531 = const(int, -1)  :: pyobject
#              #   $0.533 = $const0.531 * h10  :: pyobject
#              #   del $const0.531
#              #   $0.535 = $0.533 * h1  :: pyobject
#              #   del $0.533
#              #   $0.537 = $0.535 * h3  :: pyobject
#              #   del $0.535
#              #   $0.539 = $0.537 * h9  :: pyobject
#              #   del $0.537
#              #   $0.540 = $0.530 + $0.539  :: pyobject
#              #   del $0.539
#              #   del $0.530
#              #   $const0.543 = const(int, 2)  :: pyobject
#              #   $0.544 = h4 ** $const0.543  :: pyobject
#              #   del $const0.543
#              #   $0.545 = h3 * $0.544  :: pyobject
#              #   del $0.544
#              #   $0.547 = $0.545 * h9  :: pyobject
#              #   del $0.545
#              #   $0.548 = $0.540 + $0.547  :: pyobject
#              #   del $0.547
#              #   del $0.540
#              #   $const0.549 = const(int, -1)  :: pyobject
#              #   $0.551 = $const0.549 * h2  :: pyobject
#              #   del $const0.549
#              #   $0.553 = $0.551 * h4  :: pyobject
#              #   del $0.551
#              #   $0.555 = $0.553 * h5  :: pyobject
#              #   del $0.553
#              #   $0.557 = $0.555 * h9  :: pyobject
#              #   del $0.555
#              #   $0.558 = $0.548 + $0.557  :: pyobject
#              #   del $0.557
#              #   del $0.548
#              #   $0.559 = $0.459 * $0.558  :: pyobject
#              #   del $0.558
#              #   del $0.459
#              #   xdd = $0.559  :: pyobject
#              #   del $0.559
#
#              +(-1)*h10*h1*h3*h9+h3*h4**2*h9+(-1)*h2*h4*h5*h9))
#
# # --- LINE 50 ---
#
#
#
#     # --- LINE 51 ---
#
#     #y double dot
#
#     # --- LINE 52 ---
#
#     ydd = ((-1)*((-1)*h10*h11*h1**2+h11*h1*h2**2+h10*h1*h3**2
#
#             # --- LINE 53 ---
#
#             +h11*h1*h4**2+(-1)*h3**2*h4**2+2*h2*h3*h4*h5
#
#             # --- LINE 54 ---
#             #   $const0.560 = const(int, -1)  :: pyobject
#             #   $const0.561 = const(int, -1)  :: pyobject
#             #   $0.563 = $const0.561 * h10  :: pyobject
#             #   del $const0.561
#             #   $0.565 = $0.563 * h11  :: pyobject
#             #   del $0.563
#             #   $const0.567 = const(int, 2)  :: pyobject
#             #   $0.568 = h1 ** $const0.567  :: pyobject
#             #   del $const0.567
#             #   $0.569 = $0.565 * $0.568  :: pyobject
#             #   del $0.568
#             #   del $0.565
#             #   $0.572 = h11 * h1  :: pyobject
#             #   $const0.574 = const(int, 2)  :: pyobject
#             #   $0.575 = h2 ** $const0.574  :: pyobject
#             #   del $const0.574
#             #   $0.576 = $0.572 * $0.575  :: pyobject
#             #   del $0.575
#             #   del $0.572
#             #   $0.577 = $0.569 + $0.576  :: pyobject
#             #   del $0.576
#             #   del $0.569
#             #   $0.580 = h10 * h1  :: pyobject
#             #   $const0.582 = const(int, 2)  :: pyobject
#             #   $0.583 = h3 ** $const0.582  :: pyobject
#             #   del $const0.582
#             #   $0.584 = $0.580 * $0.583  :: pyobject
#             #   del $0.583
#             #   del $0.580
#             #   $0.585 = $0.577 + $0.584  :: pyobject
#             #   del $0.584
#             #   del $0.577
#             #   $0.588 = h11 * h1  :: pyobject
#             #   $const0.590 = const(int, 2)  :: pyobject
#             #   $0.591 = h4 ** $const0.590  :: pyobject
#             #   del $const0.590
#             #   $0.592 = $0.588 * $0.591  :: pyobject
#             #   del $0.591
#             #   del $0.588
#             #   $0.593 = $0.585 + $0.592  :: pyobject
#             #   del $0.592
#             #   del $0.585
#             #   $const0.594 = const(int, -1)  :: pyobject
#             #   $const0.596 = const(int, 2)  :: pyobject
#             #   $0.597 = h3 ** $const0.596  :: pyobject
#             #   del $const0.596
#             #   $0.598 = $const0.594 * $0.597  :: pyobject
#             #   del $const0.594
#             #   del $0.597
#             #   $const0.600 = const(int, 2)  :: pyobject
#             #   $0.601 = h4 ** $const0.600  :: pyobject
#             #   del $const0.600
#             #   $0.602 = $0.598 * $0.601  :: pyobject
#             #   del $0.601
#             #   del $0.598
#             #   $0.603 = $0.593 + $0.602  :: pyobject
#             #   del $0.602
#             #   del $0.593
#             #   $const0.604 = const(int, 2)  :: pyobject
#             #   $0.606 = $const0.604 * h2  :: pyobject
#             #   del $const0.604
#             #   $0.608 = $0.606 * h3  :: pyobject
#             #   del $0.606
#             #   $0.610 = $0.608 * h4  :: pyobject
#             #   del $0.608
#             #   $0.612 = $0.610 * h5  :: pyobject
#             #   del $0.610
#             #   $0.613 = $0.603 + $0.612  :: pyobject
#             #   del $0.612
#             #   del $0.603
#             #   $0.616 = h10 * h1  :: pyobject
#             #   $const0.618 = const(int, 2)  :: pyobject
#             #   $0.619 = h5 ** $const0.618  :: pyobject
#             #   del $const0.618
#             #   $0.620 = $0.616 * $0.619  :: pyobject
#             #   del $0.619
#             #   del $0.616
#             #   $0.621 = $0.613 + $0.620  :: pyobject
#             #   del $0.620
#             #   del $0.613
#             #   $const0.622 = const(int, -1)  :: pyobject
#             #   $const0.624 = const(int, 2)  :: pyobject
#             #   $0.625 = h2 ** $const0.624  :: pyobject
#             #   del $const0.624
#             #   $0.626 = $const0.622 * $0.625  :: pyobject
#             #   del $const0.622
#             #   del $0.625
#             #   $const0.628 = const(int, 2)  :: pyobject
#             #   $0.629 = h5 ** $const0.628  :: pyobject
#             #   del $const0.628
#             #   $0.630 = $0.626 * $0.629  :: pyobject
#             #   del $0.629
#             #   del $0.626
#             #   $0.631 = $0.621 + $0.630  :: pyobject
#             #   del $0.630
#             #   del $0.621
#             #   $const0.632 = const(int, -1)  :: pyobject
#             #   $0.633 = $0.631 ** $const0.632  :: pyobject
# ...
#                               #   del $0.887
#                               #   $0.891 = $0.889 * h3  :: pyobject
#                               #   del $0.889
#                               #   $0.893 = $0.891 * h9  :: pyobject
#                               #   del $0.891
#                               #   $0.894 = $0.884 + $0.893  :: pyobject
#                               #   del $0.893
#                               #   del $0.884
#                               #   $const0.895 = const(int, -1)  :: pyobject
#                               #   $0.897 = $const0.895 * h1  :: pyobject
#                               #   del $const0.895
#                               #   $0.899 = $0.897 * h4  :: pyobject
#                               #   del $0.897
#                               #   $0.901 = $0.899 * h5  :: pyobject
#                               #   del $0.899
#                               #   $0.903 = $0.901 * h9  :: pyobject
#                               #   del $0.901
#                               #   $0.904 = $0.894 + $0.903  :: pyobject
#                               #   del $0.903
#                               #   del $0.894
#                               #   $0.905 = $0.807 * $0.904  :: pyobject
#                               #   del $0.904
#                               #   del $0.807
#                               #   thetadd = $0.905  :: pyobject
#                               #   del $0.905
#
#                               +(-1)*h1*h4*h5*h9))
#
# # --- LINE 67 ---
#
#
#
#     # --- LINE 68 ---
#
#     #phi double dot
#
#     # --- LINE 69 ---
#
#     phidd = ((-1)*((-1)*h10*h11*h1**2+h11*h1*h2**2+h10*h1*h3**2
#
#               # --- LINE 70 ---
#
#               +h11*h1*h4**2+(-1)*h3**2*h4**2+2*h2*h3*h4*h5
#
#               # --- LINE 71 ---
#               #   $const0.906 = const(int, -1)  :: pyobject
#               #   $const0.907 = const(int, -1)  :: pyobject
#               #   $0.909 = $const0.907 * h10  :: pyobject
#               #   del $const0.907
#               #   $0.911 = $0.909 * h11  :: pyobject
#               #   del $0.909
#               #   $const0.913 = const(int, 2)  :: pyobject
#               #   $0.914 = h1 ** $const0.913  :: pyobject
#               #   del $const0.913
#               #   $0.915 = $0.911 * $0.914  :: pyobject
#               #   del $0.914
#               #   del $0.911
#               #   $0.918 = h11 * h1  :: pyobject
#               #   $const0.920 = const(int, 2)  :: pyobject
#               #   $0.921 = h2 ** $const0.920  :: pyobject
#               #   del $const0.920
#               #   $0.922 = $0.918 * $0.921  :: pyobject
#               #   del $0.921
#               #   del $0.918
#               #   $0.923 = $0.915 + $0.922  :: pyobject
#               #   del $0.922
#               #   del $0.915
#               #   $0.926 = h10 * h1  :: pyobject
#               #   $const0.928 = const(int, 2)  :: pyobject
#               #   $0.929 = h3 ** $const0.928  :: pyobject
#               #   del $const0.928
#               #   $0.930 = $0.926 * $0.929  :: pyobject
#               #   del $0.929
#               #   del $0.926
#               #   $0.931 = $0.923 + $0.930  :: pyobject
#               #   del $0.930
#               #   del $0.923
#               #   $0.934 = h11 * h1  :: pyobject
#               #   del h11
#               #   $const0.936 = const(int, 2)  :: pyobject
#               #   $0.937 = h4 ** $const0.936  :: pyobject
#               #   del $const0.936
#               #   $0.938 = $0.934 * $0.937  :: pyobject
#               #   del $0.937
#               #   del $0.934
#               #   $0.939 = $0.931 + $0.938  :: pyobject
#               #   del $0.938
#               #   del $0.931
#               #   $const0.940 = const(int, -1)  :: pyobject
#               #   $const0.942 = const(int, 2)  :: pyobject
#               #   $0.943 = h3 ** $const0.942  :: pyobject
#               #   del $const0.942
#               #   $0.944 = $const0.940 * $0.943  :: pyobject
#               #   del $const0.940
#               #   del $0.943
#               #   $const0.946 = const(int, 2)  :: pyobject
#               #   $0.947 = h4 ** $const0.946  :: pyobject
#               #   del $const0.946
#               #   $0.948 = $0.944 * $0.947  :: pyobject
#               #   del $0.947
#               #   del $0.944
#               #   $0.949 = $0.939 + $0.948  :: pyobject
#               #   del $0.948
#               #   del $0.939
#               #   $const0.950 = const(int, 2)  :: pyobject
#               #   $0.952 = $const0.950 * h2  :: pyobject
#               #   del $const0.950
#               #   $0.954 = $0.952 * h3  :: pyobject
#               #   del $0.952
#               #   $0.956 = $0.954 * h4  :: pyobject
#               #   del $0.954
#               #   $0.958 = $0.956 * h5  :: pyobject
#               #   del $0.956
#               #   $0.959 = $0.949 + $0.958  :: pyobject
#               #   del $0.958
#               #   del $0.949
#               #   $0.962 = h10 * h1  :: pyobject
#               #   $const0.964 = const(int, 2)  :: pyobject
#               #   $0.965 = h5 ** $const0.964  :: pyobject
#               #   del $const0.964
#               #   $0.966 = $0.962 * $0.965  :: pyobject
#               #   del $0.965
#               #   del $0.962
#               #   $0.967 = $0.959 + $0.966  :: pyobject
#               #   del $0.966
#               #   del $0.959
#               #   $const0.968 = const(int, -1)  :: pyobject
#               #   $const0.970 = const(int, 2)  :: pyobject
#               #   $0.971 = h2 ** $const0.970  :: pyobject
#               #   del $const0.970
#               #   $0.972 = $const0.968 * $0.971  :: pyobject
#               #   del $const0.968
#               #   del $0.971
#               #   $const0.974 = const(int, 2)  :: pyobject
#               #   $0.975 = h5 ** $const0.974  :: pyobject
#               #   del $const0.974
#               #   $0.976 = $0.972 * $0.975  :: pyobject
#               #   del $0.975
#               #   del $0.972
#               #   $0.977 = $0.967 + $0.976  :: pyobject
#               #   del $0.976
#               #   del $0.967
#               #   $const0.978 = const(int, -1)  :: pyobject
#               #   $0.979 = $0.977 ** $const0.978  :: pyobject
#               #   del $const0.978
#               #   del $0.977
#               #   $0.980 = $const0.906 * $0.979  :: pyobject
#               #   del $const0.906
#               #   del $0.979
#
#               +h10*h1*h5**2+(-1)*h2**2*h5**2)**(-1)*(h10*h1*h3*h6
#
#                             # --- LINE 72 ---
#
#                             +(-1)*h3*h4**2*h6+h2*h4*h5*h6+h2*h3*h4*h7
#
#                             # --- LINE 73 ---
#
#                             +h10*h1*h5*h7+(-1)*h2**2*h5*h7+(-1)*h1*h2*h3*h8
#
#                             # --- LINE 74 ---
#
#                             +(-1)*h1*h4*h5*h8+(-1)*h10*h1**2*h9+h1*h2**2*h9
#
#                             # --- LINE 75 ---
#                             #   $0.983 = h10 * h1  :: pyobject
#                             #   $0.985 = $0.983 * h3  :: pyobject
#                             #   del $0.983
#                             #   $0.987 = $0.985 * h6  :: pyobject
#                             #   del $0.985
#                             #   $const0.988 = const(int, -1)  :: pyobject
#                             #   $0.990 = $const0.988 * h3  :: pyobject
#                             #   del $const0.988
#                             #   $const0.992 = const(int, 2)  :: pyobject
#                             #   $0.993 = h4 ** $const0.992  :: pyobject
#                             #   del $const0.992
#                             #   $0.994 = $0.990 * $0.993  :: pyobject
#                             #   del $0.993
#                             #   del $0.990
#                             #   $0.996 = $0.994 * h6  :: pyobject
#                             #   del $0.994
#                             #   $0.997 = $0.987 + $0.996  :: pyobject
#                             #   del $0.996
#                             #   del $0.987
#                             #   $0.1000 = h2 * h4  :: pyobject
#                             #   $0.1002 = $0.1000 * h5  :: pyobject
#                             #   del $0.1000
#                             #   $0.1004 = $0.1002 * h6  :: pyobject
#                             #   del h6
#                             #   del $0.1002
#                             #   $0.1005 = $0.997 + $0.1004  :: pyobject
#                             #   del $0.997
#                             #   del $0.1004
#                             #   $0.1008 = h2 * h3  :: pyobject
#                             #   $0.1010 = $0.1008 * h4  :: pyobject
#                             #   del $0.1008
#                             #   $0.1012 = $0.1010 * h7  :: pyobject
#                             #   del $0.1010
#                             #   $0.1013 = $0.1005 + $0.1012  :: pyobject
#                             #   del $0.1012
#                             #   del $0.1005
#                             #   $0.1016 = h10 * h1  :: pyobject
#                             #   $0.1018 = $0.1016 * h5  :: pyobject
#                             #   del $0.1016
#                             #   $0.1020 = $0.1018 * h7  :: pyobject
#                             #   del $0.1018
#                             #   $0.1021 = $0.1013 + $0.1020  :: pyobject
#                             #   del $0.1020
#                             #   del $0.1013
#                             #   $const0.1022 = const(int, -1)  :: pyobject
#                             #   $const0.1024 = const(int, 2)  :: pyobject
#                             #   $0.1025 = h2 ** $const0.1024  :: pyobject
#                             #   del $const0.1024
#                             #   $0.1026 = $const0.1022 * $0.1025  :: pyobject
#                             #   del $const0.1022
#                             #   del $0.1025
#                             #   $0.1028 = $0.1026 * h5  :: pyobject
#                             #   del $0.1026
#                             #   $0.1030 = $0.1028 * h7  :: pyobject
#                             #   del h7
#                             #   del $0.1028
#                             #   $0.1031 = $0.1021 + $0.1030  :: pyobject
#                             #   del $0.1030
#                             #   del $0.1021
#                             #   $const0.1032 = const(int, -1)  :: pyobject
#                             #   $0.1034 = $const0.1032 * h1  :: pyobject
#                             #   del $const0.1032
#                             #   $0.1036 = $0.1034 * h2  :: pyobject
#                             #   del $0.1034
#                             #   $0.1038 = $0.1036 * h3  :: pyobject
#                             #   del h3
#                             #   del $0.1036
#                             #   $0.1040 = $0.1038 * h8  :: pyobject
#                             #   del $0.1038
#                             #   $0.1041 = $0.1031 + $0.1040  :: pyobject
#                             #   del $0.1040
#                             #   del $0.1031
#                             #   $const0.1042 = const(int, -1)  :: pyobject
#                             #   $0.1044 = $const0.1042 * h1  :: pyobject
#                             #   del $const0.1042
#                             #   $0.1046 = $0.1044 * h4  :: pyobject
#                             #   del $0.1044
#                             #   $0.1048 = $0.1046 * h5  :: pyobject
#                             #   del h5
#                             #   del $0.1046
#                             #   $0.1050 = $0.1048 * h8  :: pyobject
#                             #   del h8
#                             #   del $0.1048
#                             #   $0.1051 = $0.1041 + $0.1050  :: pyobject
#                             #   del $0.1050
#                             #   del $0.1041
#                             #   $const0.1052 = const(int, -1)  :: pyobject
#                             #   $0.1054 = $const0.1052 * h10  :: pyobject
#                             #   del h10
#                             #   del $const0.1052
#                             #   $const0.1056 = const(int, 2)  :: pyobject
#                             #   $0.1057 = h1 ** $const0.1056  :: pyobject
#                             #   del $const0.1056
#                             #   $0.1058 = $0.1054 * $0.1057  :: pyobject
#                             #   del $0.1057
#                             #   del $0.1054
#                             #   $0.1060 = $0.1058 * h9  :: pyobject
#                             #   del $0.1058
#                             #   $0.1061 = $0.1051 + $0.1060  :: pyobject
#                             #   del $0.1060
#                             #   del $0.1051
#                             #   $const0.1064 = const(int, 2)  :: pyobject
#                             #   $0.1065 = h2 ** $const0.1064  :: pyobject
#                             #   del h2
#                             #   del $const0.1064
#                             #   $0.1066 = h1 * $0.1065  :: pyobject
#                             #   del $0.1065
#                             #   $0.1068 = $0.1066 * h9  :: pyobject
#                             #   del $0.1066
#                             #   $0.1069 = $0.1061 + $0.1068  :: pyobject
#                             #   del $0.1068
#                             #   del $0.1061
#                             #   $const0.1072 = const(int, 2)  :: pyobject
#                             #   $0.1073 = h4 ** $const0.1072  :: pyobject
#                             #   del h4
#                             #   del $const0.1072
#                             #   $0.1074 = h1 * $0.1073  :: pyobject
#                             #   del h1
#                             #   del $0.1073
#                             #   $0.1076 = $0.1074 * h9  :: pyobject
#                             #   del h9
#                             #   del $0.1074
#                             #   $0.1077 = $0.1069 + $0.1076  :: pyobject
#                             #   del $0.1076
#                             #   del $0.1069
#                             #   $0.1078 = $0.980 * $0.1077  :: pyobject
#                             #   del $0.980
#                             #   del $0.1077
#                             #   phidd = $0.1078  :: pyobject
#                             #   del $0.1078
#
#                             +h1*h4**2*h9))
#
# # --- LINE 76 ---
#
#
#
#     # --- LINE 77 ---
#     #   $0.1079 = global(np: <module 'numpy' from 'C:\\Users\\calli\\Anaconda3\\envs\\numSolve_parallel\\lib\\site-packages\\numpy\\__init__.py'>)  :: pyobject
#     #   $0.1080 = getattr(value=$0.1079, attr=array)  :: pyobject
#     #   del $0.1079
#     #   $0.1089 = build_list(items=[Var(xd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12)), Var(yd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12)), Var(thetad, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12)), Var(phid, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (12)), Var(xdd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (49)), Var(ydd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (57)), Var(thetadd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (66)), Var(phidd, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (75))])  :: pyobject
#     #   del ydd
#     #   del yd
#     #   del xdd
#     #   del xd
#     #   del thetadd
#     #   del thetad
#     #   del phidd
#     #   del phid
#     #   $0.1090 = call $0.1080($0.1089, func=$0.1080, args=[Var($0.1089, C:\Users\calli\Documents\GitRepos\multibodyDynamics_model\Python_code\multibodyDynamics_12h.py (77))], kws=(), vararg=None)  :: pyobject
#     #   del $0.1089
#     #   del $0.1080
#     #   $0.1091 = cast(value=$0.1090)  :: pyobject
#     #   del $0.1090
#     #   return $0.1091
#
#     return(np.array([xd, yd, thetad, phid, xdd, ydd, thetadd, phidd]))
#
#
# ================================================================================

# %%
# ## Generating the simulations

tstamp_beginLoop = datetime.now()
print("Begin generating simulations loop")

#Start the "full run" loop (a.k.a. a virtual moth)
for nn in np.arange(1,FullRuns+1):
    #Note: I need to index nn starting from 1 because of filename reasons
    
    #Start the iteration of consecutive partial paths
    for i in np.arange(0,numOfPartialPaths):
        #Overall counter
        
        #This is where I would normally re-seed my random number generator.
        #[RE-SEED]
        
        #Assign randomized applied efforts (F, alpha, tau_abdomen, tau_wing)
        #F: the magnitude of the applied force
            #For LSF >= 1
        F_array = 44300*np.random.rand(numOfTrajectories)*(LengthScaleFactor**3)
            #F is a proxy for the magnitude of the aerodynamic vector in g*cm/(s^2)
            
        #alpha: the direction of the applied force
        alpha_array = 2*np.pi*np.random.rand(numOfTrajectories)
            #alpha is the angle of the aerodynamic vector with respect to 
            #the head-thorax mid-line in radians
        
        #tau0: The magnitude (and direction) of the applied abdominal torque
        tau0_array = (100000*10*(2*(np.random.rand(numOfTrajectories)-0.5))*(LengthScaleFactor**4))
            #The applied abdominal torque in g*(cm^2)/(s^2)
            
        #tau_w: The magnitude (and direction) of the applied wing torque
        if treatment == 'fa':
            #If our model is fully actuated, we want the array below
            tau_w_array = (100000*(2*(np.random.rand(numOfTrajectories)-0.5))*(LengthScaleFactor**4))
                        #The applied abdominal torque in g*(cm^2)/(s^2)
        else:
            #If our model is under-actuated, we want an array of zeros
            tau_w_array = np.zeros(numOfTrajectories) 
                        #The applied abdominal torque in g*(cm^2)/(s^2)
        
        #Define the goal criteria for y and ydot BEFORE the parallelized loop
        y_g_thisPartPath = y_g[int(goal_index[i])]; #in cm
        ydot_g_thisPartPath = ydot_g[int(goal_index[i])] #in cm/s
        
        #Pack goal criteria for this particular half wing stroke
        goalCriteria = np.array([x_g, y_g_thisPartPath, theta_g, xdot_g, 
                                 ydot_g_thisPartPath, thetadot_g])
        
#        bigQ = [None]*int(numOfTrajectories); #This will be a 100 x 8 matrix
#        cost = [None]*int(numOfTrajectories); #This will be a single value
#        NewICs = [None]*int(numOfTrajectories); #This will be an 8 x 1 vector
#        check = [None]*int(numOfTrajectories); #This will be a 4 x 1 vector
        PartPath = [None]*int(numOfTrajectories) #This will be a 4 x 1 list
        
        #Using multi-processing to generate simulations in a parallelized form
        importlib.reload(multibodyDynamics_12h)
        p = multiprocessing.Pool(MaxWorkers-1)
        stt = time.time()   
        PartPath = p.map(functools.partial(multibodyDynamics_12h.generateSimulations, 
                                     t_spray = t_spray, 
                                     q0 = q0, 
                                     F_array = F_array, 
                                     alpha_array = alpha_array, 
                                     tau0_array = tau0_array, 
                                     tau_w_array = tau_w_array, 
                                     timestep = timestep,
                                     RecedeFrac = RecedeFrac,
                                     costCoeff = costCoeff,
                                     goalCriteria = goalCriteria,
                                     globalList = globalList),
                                     range(numOfTrajectories))
            #Note bb is going to be a 2500 x 1 nested list
        parLoop_time = time.time()-stt
        print(numOfTrajectories," trajectories took ",parLoop_time, " seconds, ")
        
        #To close the multi-threading, and join the threads
        p.close()
        p.join()
        
        #When I was troubleshooting, I made this plot to see the sprays each 20ms
#        for hah in np.arange(0,numOfTrajectories):
#            x_prac = np.array(bb[hah][0][:,0])
#            y_prac = np.array(bb[hah][0][:,1])
#            plt.plot(x_prac,y_prac)
        
        #Multi-processing ends here.
        
        #Extracting the lowest cost function value location
        extractedCost = [None]*int(numOfTrajectories)
        
        for j in np.arange(0,numOfTrajectories):
            extractedCost[j] = PartPath[j][1]
        
        #Overall counter (might use this instead of i_overall)
        
        kk = kk+numOfTrajectories #DO NOT RESET
        
        #Find the indices of the lowest cost function value
        lowestCostIndex = np.where(np.array(extractedCost) == min(extractedCost)) 
        lowestCostInt = int(lowestCostIndex[0]) #Integer value of the index
#        print("Lowest cost index is: ", lowestCostInt)

        winningList = [None]*int(10)
        
        winningList[0] = q0 #The initial conditions for this spray
        winningList[1] = F_array[lowestCostInt] #F for this spray
        winningList[2] = alpha_array[lowestCostInt] #alpha for this spray
        winningList[3] = tau0_array[lowestCostInt] #abdominal torque for this spray
        winningList[4] = tau_w_array[lowestCostInt] #wing torque for this spray
        winningList[5] = PartPath[lowestCostInt][0] #StateVars for this spray
        winningList[6] = PartPath[lowestCostInt][1] #cost function value for this spray
        winningList[7] = PartPath[lowestCostInt][2] #NEW initial conditions for this spray
        winningList[8] = PartPath[lowestCostInt][3] #A 4 x 1 array of:
                                #[F, alpha, tau0, and tau_w] for this spray
        winningList[9] = parLoop_time #The run time for *this set of* 2500 sprays

#        print("The following MUST match... ")
#        print("F, alpha, tau0, tau_w are: ", winningList[1], winningList[2], winningList[3], winningList[4])
#        print("Check outputs the following: ", winningList[8])

#         PartPath = winningList;
        pre_Winstore[i] = winningList
    
        #Set the new initial conditions for the next spray
        q0 = winningList[7]
        
        #Print out the progress of the simulations
        print('On Full Run #',nn,', partial path: ', i, ' of ', 
              numOfPartialPaths)
        
#        p.close()
#        p.join()
        #End of Partial paths loop (i)
    
    #Create the filename for the saved data
    prefix = 'pre_Winstore_{}_'.format(nn+shift)
        #Reminder: nn is number of FullRuns, shift is shifting this value
    filename = prefix + suffix
    print("Filename is: ", filename)
    
    #Save the pre_Winstore file
#    savemat(filename, {'pre_Winstore': pre_Winstore}) #UNMUTE WHEN YOU WANT TO SAVE THE DATA
    
    #Now we reset our initial conditions (q0) and temporary storage (xx)
    #for the next full run.
    
    #Our initial conditions in the following order:
    #q0 = [x, y, theta, phi, xdot, ydot, thetadot, phidot]
    q0 = q0_og
    
    #A 100x8 matrix of zeros
#    xx = xx_og;

tstamp_endLoop = datetime.now()
runtime_diff = tstamp_endLoop - tstamp_beginLoop
print("Run time of loop is: ", runtime_diff)

# %%
# ## Plot the trajectories
    
for hah in np.arange(0,numOfTrajectories):
    x_prac = np.array(pre_Winstore[hah][5][:,0])
    y_prac = np.array(pre_Winstore[hah][5][:,1])
    plt.plot(x_prac,y_prac)
plt.xlabel("x (cm)")
plt.ylabel("y (cm)")
# % Plot the time elapsed for each set of sprays
time_prac = [None]*int(numOfTrajectories)

# ## Plot the time to generate simulations
for hah in np.arange(0,numOfTrajectories):
    time_prac[hah] = pre_Winstore[hah][9]
plt.plot(time_prac)
plt.xlabel("Partial Path Number")
plt.ylabel("Elapsed run time (seconds)")
plot_title = str(numOfTrajectories)+ " trajectories on "+ str(MaxWorkers)+ " cores. Treatment: " + treatment
plt.title(plot_title)
